# %% [markdown]
# # ML Course Project - Data Exploration
#
# **Team:** Yikai LAI, Zhang Yao
# **Course:** Machine Learning (PA-3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. Load Data

# %%
# TODO: Load dataset
# df = pd.read_csv('../data/raw/dataset.csv')
# df.head()

# %% [markdown]
# ## 2. Data Overview

# %%
# TODO: Basic statistics
# df.info()
# df.describe()

# %% [markdown]
# ## 3. Data Visualization

# %%
# TODO: Visualizations
